# %%
import pandas as pd

# %% [markdown]
# #### READ CSV

# %%
# Create list of columns to use
cols = ['zipcode','agi_stub','mars1','MARS2','NUMDEP']

# Create dataframe from csv using only selected columns
data = pd.read_csv("datasets/vt_tax_data_2016.csv", usecols=cols)

# View counts of dependents and tax returns by income level
print(data.groupby("agi_stub").sum())
# Out:
#           zipcode   mars1  MARS2  NUMDEP
# agi_stub
# 1         1439444  170320  28480   52490
# 2         1439444  104000  37690   64660
# 3         1439444   39160  45390   47330
# 4         1439444   11670  44410   37760
# 5         1439444    7820  67750   60730
# 6         1439444    1210  16340   16300

# %%
# Create dict specifying data types for agi_stub and zipcode
data_types = {'agi_stub':'category',
			  'zipcode':'str'}

# Load csv using dtype to set correct data types
data = pd.read_csv("datasets/vt_tax_data_2016.csv", dtype=data_types)

# Print data types of resulting frame
print(data.dtypes.head())
# Out:
# STATEFIPS       int64
# STATE             str
# zipcode           str
# agi_stub     category
# N1              int64
# dtype: object

# %%
null_values = {"zipcode": 0}

# Load csv using na_values keyword argument
data = pd.read_csv("datasets/vt_tax_data_2016.csv", na_values=null_values)

# View rows with NA ZIP codes
print(data[data.zipcode.isna()])
# Out:
#    STATEFIPS STATE  zipcode  agi_stub      N1  mars1  MARS2  MARS4   PREP  \
# 0         50    VT      NaN         1  111580  85090  14170  10740  45360
# 1         50    VT      NaN         2   82760  51960  18820  11310  35600
# 2         50    VT      NaN         3   46270  19540  22650   3620  24140
# 3         50    VT      NaN         4   30070   5830  22190    960  16060
# 4         50    VT      NaN         5   39530   3900  33800    590  22500
# 5         50    VT      NaN         6    9620    600   8150      0   7040
#
#        N2  ...  N10300  A10300  N85530  A85530  N85300  A85300  N11901  \
# 0  130630  ...   53660   50699       0       0       0       0   10820
# 1  132950  ...   74340  221146       0       0       0       0   12820
# 2   91870  ...   44860  266097       0       0       0       0   10810
# 3   71610  ...   29580  264678       0       0       0       0    7320
# 4  103710  ...   39170  731963      40      24       0       0   12500
# 5   26430  ...    9600  894432    3350    4939    4990   20428    3900
#
#    A11901  N11902  A11902
# 0    9734   88260  138337
# 1   20029   68760  151729
# 2   24499   34600   90583
# 3   21573   21300   67045
# 4   67761   23320  103034
# 5   93123    2870   39425
#
# [6 rows x 147 columns]

# %%
try:
  # Import the CSV without any keyword arguments
  data = pd.read_csv('datasets/vt_tax_data_2016.csv')
  
  # View first 5 records
  print(data.head())
  
except pd.errors.ParserError:
    print("Your data contained rows that could not be parsed.")
# Out:
#    STATEFIPS STATE  zipcode  agi_stub      N1  mars1  MARS2  MARS4   PREP  \
# 0         50    VT        0         1  111580  85090  14170  10740  45360
# 1         50    VT        0         2   82760  51960  18820  11310  35600
# 2         50    VT        0         3   46270  19540  22650   3620  24140
# 3         50    VT        0         4   30070   5830  22190    960  16060
# 4         50    VT        0         5   39530   3900  33800    590  22500
#
#        N2  ...  N10300  A10300  N85530  A85530  N85300  A85300  N11901  \
# 0  130630  ...   53660   50699       0       0       0       0   10820
# 1  132950  ...   74340  221146       0       0       0       0   12820
# 2   91870  ...   44860  266097       0       0       0       0   10810
# 3   71610  ...   29580  264678       0       0       0       0    7320
# 4  103710  ...   39170  731963      40      24       0       0   12500
#
#    A11901  N11902  A11902
# 0    9734   88260  138337
# 1   20029   68760  151729
# 2   24499   34600   90583
# 3   21573   21300   67045
# 4   67761   23320  103034
#
# [5 rows x 147 columns]

# %%
try:
  # Set warn_bad_lines to issue warnings about bad records
  data = pd.read_csv('datasets/vt_tax_data_2016.csv', 
                     error_bad_lines=False, 
                     warn_bad_lines=True)
  
  # View first 5 records
  print(data.head())
  
except pd.errors.ParserError:
    print("Your data contained rows that could not be parsed.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       6
#       7   # View first 5 records
#       8   print(data.head())
#       9
# ---> 10 except pd.errors.ParserError:
#      11     print("Your data contained rows that could not be parsed.")
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'. Did you mean 'on_bad_lines'?

# %% [markdown]
# #### READ EXCEL SHEETS

# %%
from matplotlib import pyplot as plt

# %%
excel_file = 'datasets/fcc-new-coder-survey.xlsx'

# %%
survey_responses = pd.read_excel(excel_file,skiprows=2, sheet_name='2017')

# View the head of the dataframe
print(survey_responses.head())
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# 0                   NaN                   NaN  ...                  NaN
# 1                   NaN                   NaN  ...                  NaN
# 2                   NaN                   NaN  ...                  NaN
# 3                   NaN                   NaN  ...                  NaN
# 4                   NaN                   NaN  ...                  NaN
#
#    ResourceSkillCrush  ResourceStackOverflow  ResourceTreehouse  \
# 0                 NaN                    NaN                NaN
# 1                 NaN                    1.0                NaN
# 2                 NaN                    NaN                NaN
# 3                 NaN                    1.0                NaN
# 4                 NaN                    1.0                NaN
#
#    ResourceUdacity  ResourceUdemy  ResourceW3Schools  \
# 0              NaN            1.0                1.0
# 1              NaN            1.0                1.0
# 2              1.0            1.0                NaN
# 3              NaN            NaN                NaN
# 4              NaN            NaN                NaN
#
#                               SchoolDegree             SchoolMajor  \
# 0           some college credit, no degree                     NaN
# 1           some college credit, no degree                     NaN
# 2  high school diploma or equivalent (GED)                     NaN
# 3           some college credit, no degree                     NaN
# 4                        bachelor's degree  Information Technology
#
#    StudentDebtOwe
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 98 columns]

# %%
job_prefs = survey_responses.groupby("JobPref").JobPref.count()
job_prefs.plot.barh()
plt.show()

# %%
all_survey_data = pd.read_excel(excel_file, skiprows=2, sheet_name=['2016', '2017'])

# %%
print(all_survey_data['2017'].head())
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# 0                   NaN                   NaN  ...                  NaN
# 1                   NaN                   NaN  ...                  NaN
# 2                   NaN                   NaN  ...                  NaN
# 3                   NaN                   NaN  ...                  NaN
# 4                   NaN                   NaN  ...                  NaN
#
#    ResourceSkillCrush  ResourceStackOverflow  ResourceTreehouse  \
# 0                 NaN                    NaN                NaN
# 1                 NaN                    1.0                NaN
# 2                 NaN                    NaN                NaN
# 3                 NaN                    1.0                NaN
# 4                 NaN                    1.0                NaN
#
#    ResourceUdacity  ResourceUdemy  ResourceW3Schools  \
# 0              NaN            1.0                1.0
# 1              NaN            1.0                1.0
# 2              1.0            1.0                NaN
# 3              NaN            NaN                NaN
# 4              NaN            NaN                NaN
#
#                               SchoolDegree             SchoolMajor  \
# 0           some college credit, no degree                     NaN
# 1           some college credit, no degree                     NaN
# 2  high school diploma or equivalent (GED)                     NaN
# 3           some college credit, no degree                     NaN
# 4                        bachelor's degree  Information Technology
#
#    StudentDebtOwe
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 98 columns]

# %%
sheet_names=[0, "2017"]

# %%
all_survey_data = pd.read_excel(excel_file, skiprows=2, sheet_name=sheet_names  )

# %%
print(all_survey_data['2017'].head())
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# 0                   NaN                   NaN  ...                  NaN
# 1                   NaN                   NaN  ...                  NaN
# 2                   NaN                   NaN  ...                  NaN
# 3                   NaN                   NaN  ...                  NaN
# 4                   NaN                   NaN  ...                  NaN
#
#    ResourceSkillCrush  ResourceStackOverflow  ResourceTreehouse  \
# 0                 NaN                    NaN                NaN
# 1                 NaN                    1.0                NaN
# 2                 NaN                    NaN                NaN
# 3                 NaN                    1.0                NaN
# 4                 NaN                    1.0                NaN
#
#    ResourceUdacity  ResourceUdemy  ResourceW3Schools  \
# 0              NaN            1.0                1.0
# 1              NaN            1.0                1.0
# 2              1.0            1.0                NaN
# 3              NaN            NaN                NaN
# 4              NaN            NaN                NaN
#
#                               SchoolDegree             SchoolMajor  \
# 0           some college credit, no degree                     NaN
# 1           some college credit, no degree                     NaN
# 2  high school diploma or equivalent (GED)                     NaN
# 3           some college credit, no degree                     NaN
# 4                        bachelor's degree  Information Technology
#
#    StudentDebtOwe
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 98 columns]

# %%
all_survey_data['2017'].isna().sum()
# Out:
# Age                   21
# AttendedBootcamp      14
# BootcampFinish       873
# BootcampLoanYesNo    872
# BootcampName         881
#                     ...
# ResourceUdemy        692
# ResourceW3Schools    457
# SchoolDegree          20
# SchoolMajor          416
# StudentDebtOwe       718
# Length: 98, dtype: int64

# %%
survey_subset = pd.read_excel(excel_file, 
                              dtype={"HasDebt": bool,
                              "AttendedBootCampYesNo": bool},
                                true_values=["Yes"],
                              false_values=["No"])
# View the data
print(survey_subset.head())
# Out:
#    FreeCodeCamp New Developer Survey Responses, 2016        Unnamed: 1  \
# 0  Source: https://www.kaggle.com/freecodecamp/20...               NaN
# 1                                                Age  AttendedBootcamp
# 2                                                 28                 0
# 3                                                 22                 0
# 4                                                 19                 0
#
#        Unnamed: 2         Unnamed: 3    Unnamed: 4         Unnamed: 5  \
# 0             NaN                NaN           NaN                NaN
# 1  BootcampFinish  BootcampLoanYesNo  BootcampName  BootcampRecommend
# 2             NaN                NaN           NaN                NaN
# 3             NaN                NaN           NaN                NaN
# 4             NaN                NaN           NaN                NaN
#
#        Unnamed: 6                     Unnamed: 7            Unnamed: 8  \
# 0             NaN                            NaN                   NaN
# 1  ChildrenNumber                 CityPopulation  CodeEventConferences
# 2             NaN  between 100,000 and 1 million                   NaN
# 3             NaN  between 100,000 and 1 million                   NaN
# 4             NaN            more than 1 million                   NaN
#
#              Unnamed: 9  ...          Unnamed: 88         Unnamed: 89  \
# 0                   NaN  ...                  NaN                 NaN
# 1  CodeEventDjangoGirls  ...  ResourcePluralSight  ResourceSkillCrush
# 2                   NaN  ...                  NaN                 NaN
# 3                   NaN  ...                  NaN                 NaN
# 4                   NaN  ...                  NaN                 NaN
#
#              Unnamed: 90        Unnamed: 91      Unnamed: 92    Unnamed: 93  \
# 0                    NaN                NaN              NaN            NaN
# 1  ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN              1
# 4                    NaN                NaN              NaN            NaN
#
#          Unnamed: 94                              Unnamed: 95  Unnamed: 96  \
# 0                NaN                                      NaN          NaN
# 1  ResourceW3Schools                             SchoolDegree  SchoolMajor
# 2                NaN           some college credit, no degree          NaN
# 3                NaN           some college credit, no degree          NaN
# 4                NaN  high school diploma or equivalent (GED)          NaN
#
#       Unnamed: 97
# 0             NaN
# 1  StudentDebtOwe
# 2           20000
# 3             NaN
# 4             NaN
#
# [5 rows x 98 columns]

# %%
survey_data = pd.read_excel(excel_file, skiprows=2, sheet_name=0, parse_dates=["Part1StartTime"])
print(survey_data.Part1StartTime.head())

print(survey_data.Part1StartTime.head())
# Out:
# 0   2016-03-29 21:23:13
# 1   2016-03-29 21:24:59
# 2   2016-03-29 21:25:37
# 3   2016-03-29 21:21:37
# 4   2016-03-29 21:26:22
# Name: Part1StartTime, dtype: datetime64[us]
# 0   2016-03-29 21:23:13
# 1   2016-03-29 21:24:59
# 2   2016-03-29 21:25:37
# 3   2016-03-29 21:21:37
# 4   2016-03-29 21:26:22
# Name: Part1StartTime, dtype: datetime64[us]

# %%
dateformat = "%m%d%Y %H:%M:%S"
dateformat = "%Y-%m-%d %H:%M:%S"
survey_data["Part2EndTime"] = pd.to_datetime(survey_data["Part2EndTime"], format=dateformat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 dateformat = "%m%d%Y %H:%M:%S"
# ----> 2 survey_data["Part2EndTime"] = pd.to_datetime(survey_data["Part2EndTime"], format=dateformat)
#
# File c:\Users\compumarts\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\compumarts\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\compumarts\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\tools\datetimes.py:470, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     459 def _array_strptime_with_fallback(
#     460     arg,
#     461     name,
#    (...)    465     errors: str,
#     466 ) -> Index:
#     467     """
#     468     Call array_strptime, with fallback behavior depending on 'errors'.
#     469     """
# --> 470     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     471     if tz_out is not None:
#     472         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:563, in pandas._libs.tslibs.strptime.array_strptime()
# --> 563 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/strptime.pyx:511, in pandas._libs.tslibs.strptime.array_strptime()
# --> 511 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/strptime.pyx:617, in pandas._libs.tslibs.strptime._parse_with_format()
# --> 617 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: time data "2016-03-29 21:27:25" doesn't match format "%m%d%Y %H:%M:%S". You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
